# %%
import sys
import time
sys.setrecursionlimit(9999999)
# Autor: Daniel Quispe Taboada

# %%
class Node:
    def __init__(self, data, son=None):
        self.data = data
        self.son = None
        self.father = None
        self.cost = None
        self.set_son(son)

    def set_son(self, son):
        self.son = son
        if self.son is not None:
            for s in self.son:
                s.father = self

    def get_son(self):
        return self.son

    def get_father(self):
        return self.father

    def set_father(self, father):
        self.father = father

    def set_data(self, data):
        self.data = data

    def get_data(self):
        return self.data

    def set_cost(self, cost):
        self.cost = cost

    def get_cost(self):
        return self.cost

    def equal(self, node):
        if self.get_data() == node.get_data():
            return True
        else:
            return False

    def on_list(self, node_list):
        listed = False
        for n in node_list:
            if self.equal(n):
                listed = True
        return listed

    def __str__(self):
        return str(self.get_data())

# %%
# Se encarga de decidir si el signo de la ecuacion es mas '+' o menos '-', devolviendo cual sea
def masomenos(l1, l2):
    contador = 0
    resultado = ''
    if l1 == 'p':
        contador += 1
    if l2 == 'p':
        contador += 1
    if contador == 2:
        resultado = '+'
    if contador == 1:
        resultado = '-'
    return resultado

# %%
# Esta funcion se encarga a partir de un estado, pudiendo ser inicial, solucion o de otro, este se puede guardar en otra matriz para posteriormente mostrarla
def matrizar(l):
    lista = [['is', l[0][1]+'h',       'ds', ' ',                        ' ', ' ',         'is', l[9][1]+'h',          'ds', ' ', ' ', ' ',         'is', l[16][1]+'h',         'ds', ],
             [l[1][1]+'v',         ' ', l[2][1]+'v', ' ',                        ' ', ' ', l[10][1]+'v',
                 ' ', l[11][1]+'v', ' ', '─', ' ', l[17][1]+'v',          ' ', l[18][1]+'v', ],
             ['m', l[3][1]+'h',         'm', ' ', masomenos(l[7][1], l[8][1]), ' ',          'm',
              l[12][1]+'h',          'm', ' ', ' ', ' ',          'm', l[19][1]+'h',          'm', ],
             [l[4][1]+'v',         ' ', l[5][1]+'v', ' ',                        ' ', ' ', l[13][1]+'v',
                 ' ', l[14][1]+'v', ' ', '─', ' ', l[20][1]+'v',          ' ', l[21][1]+'v', ],
             ['ii', l[6][1]+'h',        'di', ' ',                        ' ', ' ',         'ii',
                 l[15][1]+'h',         'di', ' ', ' ', ' ',         'ii', l[22][1]+'h',         'di', ]
             ]
    return lista

# %%
# La funcion se encagra de ponerle los espacios vacios que quedan, y lo palitos dependiendo si son vericales u horizontal, listo para imprimir por consola
def graficar(lista):
    grafica = lista.copy()
    for i in range(0, len(lista)):
        for j in range(0, len(lista[i])):
            if lista[i][j] == 'vh' or lista[i][j] == 'vv':
                caracter = ' '
            elif lista[i][j] == 'ph':
                caracter = '─'
            elif lista[i][j] == 'pv':
                caracter = '│'
            elif lista[i][j] == '─':
                caracter = '─'
            elif lista[i][j] == 'is':
                caracter = '·'
            elif lista[i][j] == 'ds':
                caracter = '·'
            elif lista[i][j] == 'ii':
                caracter = '·'
            elif lista[i][j] == 'di':
                caracter = '·'
            elif lista[i][j] == 'm':
                caracter = '·'
            elif lista[i][j] == '-' or lista[i][j] == '+':
                caracter = lista[i][j]
            else:
                caracter = ' '
            grafica[i][j] = caracter
    return grafica

# %%
# Imprimir se encarga como su nombre lo dice, muestra ya la data que se pasa como parametro
def imprimir(li):
    for line in li:
        print(''.join(map(str, line)))

# %%
# La solucion se busca recursivamente, ademas que hace uso de la heuristica, esto realiza un ordenamiento de lo numeros, 
# de un estado inicial, '4 - 2 = 9', hasta un estado final u objetivo, que es el '7 + 2 = 9'
def Solucion_Heuristica_de_Busqueda(init_node, solution, visited):
    visited.append(init_node.get_data())
    if init_node.get_data() == solution:
        return init_node
    else:
        # Expandir nodos sucesores (hijos)
        node_data = init_node.get_data()
        son_nodes = []
        for i in range(0, len(node_data)-1):
            son_data = node_data.copy()
            data = son_data[i]
            son_data[i] = son_data[i+1]
            son_data[i+1] = data
            son_nodes.append(Node(son_data))
        init_node.set_son(son_nodes)

        for son_node in init_node.get_son():
            if not son_node.get_data() in visited and heuristics(init_node, son_node):
                solutn = Solucion_Heuristica_de_Busqueda(
                    son_node, solution, visited)
                if solutn is not None:
                    return solutn
        return None

# Ve cual es mejor, si el nodo padre o su nodo hijo, segun al ordenamiento que realiza
def heuristics(father_node, son_node):
    father_quality = 0
    son_quality = 0
    father_data = father_node.get_data()
    son_data = son_node.get_data()
    for n in range(1, len(father_data)):
        if father_data[n][0] >= father_data[n - 1][0]:
            father_quality += 1
        if son_data[n][0] >= son_data[n - 1][0]:
            son_quality += 1
    return son_quality >= father_quality

# %%
if __name__ == "__main__":
    # Se pone los palitos de acuerdo a su numeracion
    # y tambien los espacios vacios donde se puede mover, 
    # "v" es vacio y "p" esta el palito
    initial_state = [
        [2, "v"], [1, "p"], [3, "p"], [8, "p"], [5, "v"], [6, "p"], [7, "v"],
        [4, "v"], [9, "p"],
        [10, "p"], [11, "v"], [12, "p"], [13, "p"], [14, "p"], [15, "v"], [16, "p"],
        [17, "p"], [18, "p"], [19, "p"], [20, "p"], [21, "v"], [22, "p"], [23, "p"],
    ]

    solution_state = [
        [1, "p"], [2, "v"], [3, "p"], [4, "v"], [5, "v"], [6, "p"], [7, "v"],
        [8, "p"], [9, "p"],
        [10, "p"], [11, "v"], [12, "p"], [13, "p"], [14, "p"], [15, "v"], [16, "p"],
        [17, "p"], [18, "p"], [19, "p"], [20, "p"], [21, "v"], [22, "p"], [23, "p"],
    ]  
    visited_nodes = []
    initial_node = Node(initial_state)
    tiempo_inicio = time.time()
    solution_node = Solucion_Heuristica_de_Busqueda(
        initial_node, solution_state, visited_nodes)
    tiempo_final = time.time()
    result = []
    node = solution_node
    if node is not None:
        while node.get_father() is not None:
            result.append(node.get_data())
            node = node.get_father()

        result.append(initial_state)
        result.reverse()

        nodo = 1
        for valor in result:
            print("iteracion: "+str(nodo), end="\n")
            imprimir(graficar(matrizar(valor)))
            nodo += 1
            print()
    else:
        print("No hay solución")
    print("Tiempo demorado: ", round(tiempo_final-tiempo_inicio, 2), "s.")
# Out:
# iteracion: 1
# · ·   ·─·   ·─·
# │ │     │ ─ │ │
# ·─· - ·─·   ·─·
#   │   │   ─   │
# · ·   ·─·   ·─·
#
# iteracion: 2
# ·─·   ·─·   ·─·
#   │     │ ─ │ │
# ·─· - ·─·   ·─·
#   │   │   ─   │
# · ·   ·─·   ·─·
#
# iteracion: 3
# ·─·   ·─·   ·─·
#   │     │ ─ │ │
# ·─· - ·─·   ·─·
#   │   │   ─   │
# · ·   ·─·   ·─·
#
# iteracion: 4
# ·─·   ·─·   ·─·
# │       │ ─ │ │
# ·─· - ·─·   ·─·
#   │   │   ─   │
# · ·   ·─·   ·─·
#
# iteracion: 5
# ·─·   ·─·   ·─·
# │       │ ─ │ │
# ·─· - ·─·   ·─·
#   │   │   ─   │
# · ·   ·─·   ·─·
#
# iteracion: 6
# ·─·   ·─·   ·─·
# │       │ ─ │ │
# ·─· - ·─·   ·─·
#   │   │   ─   │
# · ·   ·─·   ·─·
#
# iteracion: 7
# ·─·   ·─·   ·─·
# │       │ ─ │ │
# ·─· - ·─·   ·─·
#   │   │   ─   │
# · ·   ·─·   ·─·
#
# iteracion: 8
# ·─·   ·─·   ·─·
#   │     │ ─ │ │
# ·─· - ·─·   ·─·
#   │   │   ─   │
# · ·   ·─·   ·─·
#
# iteracion: 9
# ·─·   ·─·   ·─·
#   │     │ ─ │ │
# ·─· - ·─·   ·─·
#   │   │   ─   │
# · ·   ·─·   ·─·
#
# iteracion: 10
# ·─·   ·─·   ·─·
#   │     │ ─ │ │
# · · - ·─·   ·─·
# │ │   │   ─   │
# · ·   ·─·   ·─·
#
# iteracion: 11
# ·─·   ·─·   ·─·
#   │     │ ─ │ │
# · · - ·─·   ·─·
# │ │   │   ─   │
# · ·   ·─·   ·─·
#
# iteracion: 12
# ·─·   ·─·   ·─·
#   │     │ ─ │ │
# · · - ·─·   ·─·
# │ │   │   ─   │
# · ·   ·─·   ·─·
#
# iteracion: 13
# ·─·   ·─·   ·─·
#   │     │ ─ │ │
# · · - ·─·   ·─·
# │     │   ─   │
# ·─·   ·─·   ·─·
#
# iteracion: 14
# ·─·   ·─·   ·─·
#   │     │ ─ │ │
# · · + ·─·   ·─·
# │     │   ─   │
# · ·   ·─·   ·─·
#
# iteracion: 15
# ·─·   ·─·   ·─·
#   │     │ ─ │ │
# · · + ·─·   ·─·
# │     │   ─   │
# · ·   ·─·   ·─·
#
# iteracion: 16
# ·─·   ·─·   ·─·
#   │     │ ─ │ │
# · · + ·─·   ·─·
#   │   │   ─   │
# · ·   ·─·   ·─·
#
# iteracion: 17
# ·─·   ·─·   ·─·
#   │     │ ─ │ │
# · · + ·─·   ·─·
#   │   │   ─   │
# · ·   ·─·   ·─·
#
# Tiempo demorado:  0.04 s.
